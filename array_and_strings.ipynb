# %% [markdown]
# Array
# ![image.png](attachment:image.png)

# %% [markdown]
# This picture shows how python stores the array, it stores the pointer to the first element of the array inside the variable, and the array itself is stored in the heap.
