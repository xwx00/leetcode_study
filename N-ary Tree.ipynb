# %% [markdown]
# # Introduction
#
# N-ary trees are a generalization of binary trees. Each node in an n-ary tree can have at most *N* children.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Preorder, postorder and level-order traversal are suitable to be extended to an N-ary tree.
#
# *Note:* inorder traversal is not suitable to be extended to an N-ary tree, because there is no unique way to define the order of visiting nodes, it can be:
#
#     child[0] → Root → child[1], child[2], child[3], ...
# or
#
#     child[0], child[1] → Root → child[2], child[3], ...
#
# or
#
#     child[0] → child[1] → Root → child[2], child[3], ...

# %% [markdown]
# # Classical Recursion Solution of N-ary Tree
#
# ## Top-down Solution:
#
#     "Top-down" means that in each recursion level, we will visit the node first to come up with some values, and pass these values to its children when calling the function recursively.
#
#     so: parent -> do something -> pass the result to children
#
# ![image.png](attachment:image.png)
#
#     "Bottom-up" means that in each recursion level, we will firstly call the functions recursively for all the children nodes and then come up with the answer according to the return values, and return the answer to its parent node.
#
#     so: children-> do something -> pass the result to parent
#
# ## Bottom-up Solution:
# ![image-2.png](attachment:image-2.png)
